# %%
# !pip install emot
# Out:
# Collecting emot
#   Downloading emot-3.1-py3-none-any.whl.metadata (396 bytes)
# Downloading emot-3.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: emot
# Successfully installed emot-3.1

# %%
text1="What  are saying 😂. I am the boss ✨ and why are u so 💀"

# %%
import re
from emot.emo_unicode import UNICODE_EMOJI
from emot.emo_unicode import EMOTICONS_EMO

# %%
def converting_emojis(text):
  for emot in UNICODE_EMOJI:
    text= text.replace(emot, "_".join(UNICODE_EMOJI[emot].replace(",","").replace(":","").split()))
  return text
converting_emojis(text1)
# Out:
# 'What  are saying face_with_tears_of_joy. I am the boss sparkles and why are u so skull'

# %%
import re

def emoji_removal(string):
    emoji_unicodes = re.compile("["
                                u"\U0001F600-\U0001F64F"  # Emoticons
                                u"\U0001F300-\U0001F5FF"  # Symbols & pictographs
                                u"\U0001F680-\U0001F6FF"  # Transport & map symbols
                                u"\U0001F1E0-\U0001F1FF"  # Flags (iOS)
                                u"\U00002500-\U00002BEF"  # Chinese, Japanese, Korean characters
                                u"\U00002702-\U000027B0"  # Dingbats
                                u"\U000024C2-\U0001F251"  # Enclosed characters
                                u"\U0001F926-\U0001F937"  # Gesture emojis
                                u"\U00010000-\U0010FFFF"  # Supplementary characters
                                u"\u2640-\u2642"  # Gender symbols
                                u"\u2600-\u26FF"  # Miscellaneous symbols
                                "]", flags=re.UNICODE)

    return emoji_unicodes.sub(r'', string)
emoji_removal(text1)
# Out:
# 'What  are saying . I am the boss  and why are u so '
